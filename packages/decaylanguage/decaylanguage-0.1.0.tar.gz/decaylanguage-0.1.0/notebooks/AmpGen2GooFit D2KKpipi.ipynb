# %% [markdown]
# # AmpGen2GooFit.py

# %%
import sys
sys.path.append('..')

# %%
from decaylanguage.particle import Particle, SpinType
from decaylanguage.decay.goofit import GooFitChain, SF_4Body, known_spinfactors
from IPython.display import display, display_html
import pandas as pd
import datetime
from functools import partial

# %%
import ipywidgets as widgets

# %%
cb = widgets.Checkbox(False, description="Print to file")
cb
# Out:
# Checkbox(value=False, description='Print to file')

# %%
from plumbum import colors

if cb.value:
    f = open('DtoKKpipi_v1.cu', 'w')
    print = partial(print, file=f)
    colors.use_color = False
else:
    colors.use_color = 2

# %%
lines, all_states = GooFitChain.read_AmpGen('D0toKKpipi_model_v1.txt')

# %%
print(r'/* Autogenerated file by AmpGen2GooFit')
print('Generated on ', datetime.datetime.now())
# Out:
# /* Autogenerated file by AmpGen2GooFit
# Generated on  2018-02-01 14:28:22.231288

# %%
print('\n')
for seen_factor in {p.spindetails() for p in lines}:
    my_lines = [p for p in lines if p.spindetails()==seen_factor]
    try:
        print(colors.bold | seen_factor, ":", *my_lines[0].spinfactors)
        color = colors.blue
    except RuntimeError:
        print(colors.bold | seen_factor, ":", "MISSING")
        color = colors.red
    for line in my_lines:
        print(' ', color | str(line))
# Out:
# DtoV1V2_V1toP1P2_V2toP3P4 : SF_4Body.DtoV1V2_V1toP1P2_V2toP3P4_S
#   D0[S]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}
#   D0[S]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}
#   D0[S]{phi(1020)0{K+,K-},omega(782)0{pi+,pi-}}
# DtoA1P1_A1toERRORP2_ERRORtoP3P4 : MISSING
#   D0{K(1)(1270)~-,K+}
# DtoV1V2_V1toP1P2_V2toP3P4_P : SF_4Body.DtoV1V2_V1toP1P2_V2toP3P4_P SF_4Body.FF_12_34_L1
#   D0[P]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}
#   D0[P]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}
# DtoS1S2_S1toP1P2_S2toP3P4 : SF_4Body.ONE
#   D0{KPi00[FOCUS.Kpi]{K-,pi+},KPi10[FOCUS.Kpi]{K+,pi-}}
# DtoA1P1_A1toS2P2_S2toP3P4 : SF_4Body.DtoAP1_AtoSP2_StoP3P4 SF_4Body.FF_123_4_L1
#   D0{K(1)(1270)+[GSpline.EFF]{KPi10[FOCUS.Kpi]{K+,pi-},pi+},K-}
# DtoA1P1_A1toV2P2_V2toP3P4 : SF_4Body.DtoAP1_AtoVP2Dwave_VtoP3P4 SF_4Body.FF_123_4_L1
#   D0{a(1)(1260)+[S;GSpline.EFF]{K(892)~0{K-,pi+},K+},pi-}
#   D0{K(1)(1270)+[GSpline.EFF]{K(892)0{K+,pi-},pi+},K-}
#   D0{K(1)(1270)+[GSpline.EFF]{omega(782)0{pi-,pi+},K+},K-}
#   D0{K(1)(1270)+[GSpline.EFF]{rho(770)0{pi-,pi+},K+},K-}
#   D0{K(1)(1400)+[S]{K(892)0{K+,pi-},pi+},K-}
#   D0{K(1)(1400)~-[S]{K(892)~0{K-,pi+},pi-},K+}
# DtoV1S2_V1toP1P2_S2toP3P4_P : MISSING
#   D0[P]{K0{K+,pi-},KPi00[FOCUS.Kpi]{K-,pi+}}
#   D0[P]{K~0{K-,pi+},KPi10[FOCUS.Kpi]{K+,pi-}}
#   D0[P]{K(892)0{K+,pi-},KPi00[FOCUS.Kpi]{K-,pi+}}
#   D0[P]{phi(1020)0{K+,K-},PiPi00[kMatrix.prod.0]{pi+,pi-}}
# DtoV1V2_V1toP1P2_V2toP3P4_D : SF_4Body.DtoV1V2_V1toP1P2_V2toP3P4_D SF_4Body.FF_12_34_L2
#   D0[D]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}
#   D0[D]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}
# Dtos1P1_s1toS2P2_S2toP3P4 : SF_4Body.DtoPP1_PtoSP2_StoP3P4
#   D0{K(1460)+[S;GSpline.EFF]{PiPi10[kMatrix.prod.1]{pi+,pi-},K+},K-}
#   D0{K(1460)~-[S;GSpline.EFF]{PiPi10[kMatrix.prod.1]{pi+,pi-},K-},K+}
# DtoV1P1_V1toV2P2Pwave_V2toP3P4 : MISSING
#   D0{K+[P]{K(892)0{K+,pi-},pi+},K-}
#   D0{K~-[P]{K(892)~0{K-,pi+},pi-},K+}
# DtoA1P1_A1toV2P2Dwave_V2toP3P4 : SF_4Body.DtoAP1_AtoVP2Dwave_VtoP3P4 SF_4Body.FF_123_4_L1
#   D0{K(1)(1270)+[D;GSpline.EFF]{K(892)0{K+,pi-},pi+},K-}
# DtoS1V2_S1toP1P2_V2toP3P4_P : MISSING
#   D0[P]{KK00[kMatrix.prodKK.0]{K+,K-},rho(770)0{pi+,pi-}}

# %%
print('\n')
for spintype in SpinType:
    ps = [format(str(p), '11') for p in GooFitChain.all_particles if p.spintype == spintype]
    print(f"{spintype.name:>12}:", *ps)
# Out:
#       Scalar: PiPi00      PiPi10      KPi00       KPi10       KK00
# PseudoScalar: K+          pi+         K(1460)+    K(1460)~-   D0          pi-         K-
#       Vector: K(892)~0    phi(1020)0  K~-         K~0         omega(782)0 K0          rho(770)0   K+          K(892)0
#        Axial: K(1)(1270)+ K(1)(1400)~- K(1)(1400)+ K(1)(1270)~- a(1)(1260)+
#       Tensor:
# PseudoTensor:
#      Unknown:

# %%
print('\n')
for n, line in enumerate(lines):
    try:
        sf = len(line.spinfactors)
        p = colors.blue.print
    except RuntimeError as e:
        sf = ' '
        p = colors.red.print
    p(f'{n:2} {str(line):<70} spinfactors: {sf}  L: {line.L} [{line.L_range()[0]}-{line.L_range()[1]}]')
# Out:
#  0 D0[S]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}                            spinfactors: 1  L: 0 [0-2]
#  1 D0[P]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}                            spinfactors: 2  L: 1 [0-2]
#  2 D0[D]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}                            spinfactors: 2  L: 2 [0-2]
#  3 D0[S]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}                                spinfactors: 1  L: 0 [0-2]
#  4 D0[P]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}                                spinfactors: 2  L: 1 [0-2]
#  5 D0[D]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}                                spinfactors: 2  L: 2 [0-2]
#  6 D0[P]{K0{K+,pi-},KPi00[FOCUS.Kpi]{K-,pi+}}                             spinfactors:    L: 1 [1-1]
#  7 D0[P]{K~0{K-,pi+},KPi10[FOCUS.Kpi]{K+,pi-}}                            spinfactors:    L: 1 [1-1]
#  8 D0[P]{K(892)0{K+,pi-},KPi00[FOCUS.Kpi]{K-,pi+}}                        spinfactors:    L: 1 [1-1]
#  9 D0[P]{KK00[kMatrix.prodKK.0]{K+,K-},rho(770)0{pi+,pi-}}                spinfactors:    L: 1 [1-1]
# 10 D0[P]{phi(1020)0{K+,K-},PiPi00[kMatrix.prod.0]{pi+,pi-}}               spinfactors:    L: 1 [1-1]
# 11 D0[S]{phi(1020)0{K+,K-},omega(782)0{pi+,pi-}}                          spinfactors: 1  L: 0 [0-2]
# 12 D0{a(1)(1260)+[S;GSpline.EFF]{K(892)~0{K-,pi+},K+},pi-}                spinfactors: 2  L: 1 [1-1]
# 13 D0{K(1)(1270)+[D;GSpline.EFF]{K(892)0{K+,pi-},pi+},K-}                 spinfactors: 2  L: 1 [1-1]
# 14 D0{K(1)(1270)+[GSpline.EFF]{K(892)0{K+,pi-},pi+},K-}                   spinfactors: 2  L: 1 [1-1]
# 15 D0{K(1)(1270)+[GSpline.EFF]{KPi10[FOCUS.Kpi]{K+,pi-},pi+},K-}          spinfactors: 2  L: 1 [1-1]
# 16 D0{K(1)(1270)+[GSpline.EFF]{omega(782)0{pi-,pi+},K+},K-}               spinfactors: 2  L: 1 [1-1]
# 17 D0{K(1)(1270)+[GSpline.EFF]{rho(770)0{pi-,pi+},K+},K-}                 spinfactors: 2  L: 1 [1-1]
# 18 D0{K(1)(1270)~-,K+}                                                    spinfactors:    L: 1 [1-1]
# 19 D0{K(1)(1400)+[S]{K(892)0{K+,pi-},pi+},K-}                             spinfactors: 2  L: 1 [1-1]
# 20 D0{K(1)(1400)~-[S]{K(892)~0{K-,pi+},pi-},K+}                           spinfactors: 2  L: 1 [1-1]
# 21 D0{K(1460)+[S;GSpline.EFF]{PiPi10[kMatrix.prod.1]{pi+,pi-},K+},K-}     spinfactors: 1  L: 0 [0-0]
# 22 D0{K(1460)~-[S;GSpline.EFF]{PiPi10[kMatrix.prod.1]{pi+,pi-},K-},K+}    spinfactors: 1  L: 0 [0-0]
# 23 D0{K+[P]{K(892)0{K+,pi-},pi+},K-}                                      spinfactors:    L: 1 [1-1]
# 24 D0{K~-[P]{K(892)~0{K-,pi+},pi-},K+}                                    spinfactors:    L: 1 [1-1]
# 25 D0{KPi00[FOCUS.Kpi]{K-,pi+},KPi10[FOCUS.Kpi]{K+,pi-}}                  spinfactors: 1  L: 0 [0-0]

# %% [markdown]
# ### We can make the GooFit Intro code:

# %%
known = known_spinfactors.keys()
found = {line.spindetails() for line in lines}

print('All found spin configurations:')
for sf in sorted(found & known):
    print(" ", colors.blue | sf)

if found - known:
    print('\nAll missing spin configurations:')

    for sf in sorted(found - known):
        print(" ", colors.red | sf)

    print('\nAll remaining spin configurations:')

    for sf in sorted(known - found):
        print(" ", colors.green | sf)
# Out:
# All found spin configurations:
#   DtoA1P1_A1toS2P2_S2toP3P4
#   DtoA1P1_A1toV2P2Dwave_V2toP3P4
#   DtoA1P1_A1toV2P2_V2toP3P4
#   DtoS1S2_S1toP1P2_S2toP3P4
#   DtoV1V2_V1toP1P2_V2toP3P4
#   DtoV1V2_V1toP1P2_V2toP3P4_D
#   DtoV1V2_V1toP1P2_V2toP3P4_P
#   Dtos1P1_s1toS2P2_S2toP3P4
#
# All missing spin configurations:
#   DtoA1P1_A1toERRORP2_ERRORtoP3P4
#   DtoS1V2_S1toP1P2_V2toP3P4_P
#   DtoV1P1_V1toV2P2Pwave_V2toP3P4
#   DtoV1S2_V1toP1P2_S2toP3P4_P
#
# All remaining spin configurations:
#   DtoT1P1_T1toV2P2_V2toP3P4
#   DtoV1S2_V1toP1P2_S2toP3P4
#   Dtos1P1_s1toV2P2_V2toP3P4

# %%
print('\n*/\n\n    // Intro')
print(GooFitChain.make_intro(all_states))
# Out:
# */
#
#     // Intro
#     // Event type: D0 ->  K+ (0)   K- (1)   pi+ (2)   pi- (3)
#
#     std::vector<std::vector<Lineshape*>> line_factor_list;
#     std::vector<std::vector<SpinFactor*>> spin_factor_list;
#     std::vector<Amplitude*> amplitudes_list;
#
#     constexpr fptype K_P      { 0.493677       };
#     constexpr fptype D_0      { 1.86484        };
#     constexpr fptype PI_M     { 0.13957018     };
#     constexpr fptype PI_P     { 0.13957018     };
#     constexpr fptype K_M      { 0.493677       };
#
#     Variable K892_0_M        { "K892_0_M"           , 0.896      };
#     Variable K892_0_W        { "K892_0_W"           , 0.0503     };
#     Variable phi1020_0_M     { "phi1020_0_M"        , 1.019455   };
#     Variable phi1020_0_W     { "phi1020_0_W"        , 0.00426    };
#     Variable K_m_M           { "K_m_M"              , 1.717      };
#     Variable K_m_W           { "K_m_W"              , 0.32       };
#     Variable PiPi0_0_M       { "PiPi0_0_M"          , 9.99       };
#     Variable PiPi0_0_W       { "PiPi0_0_W"          , 9900000.0  };
#     Variable K11270_p_M      { "K11270_p_M"         , 1.272      };
#     Variable K11270_p_W      { "K11270_p_W"         , 0.09       };
#     Variable PiPi1_0_M       { "PiPi1_0_M"          , 9.99       };
#     Variable PiPi1_0_W       { "PiPi1_0_W"          , 9900000.0  };
#     Variable K_0_M           { "K_0_M"              , 1.717      };
#     Variable K_0_W           { "K_0_W"              , 0.32       };
#     Variable K11400_m_M      { "K11400_m_M"         , 1.403      };
#     Variable K11400_m_W      { "K11400_m_W"         , 0.174      };
#     Variable KPi0_0_M        { "KPi0_0_M"           , 9.99       };
#     Variable KPi0_0_W        { "KPi0_0_W"           , 9900000.0  };
#     Variable omega782_0_M    { "omega782_0_M"       , 0.78265    };
#     Variable omega782_0_W    { "omega782_0_W"       , 0.00849    };
#     Variable KPi1_0_M        { "KPi1_0_M"           , 9.99       };
#     Variable KPi1_0_W        { "KPi1_0_W"           , 9900000.0  };
#     Variable K1460_p_M       { "K1460_p_M"          , 1.46       };
#     Variable K1460_p_W       { "K1460_p_W"          , 0.26       };
#     Variable K1460_m_M       { "K1460_m_M"          , 1.46       };
#     Variable K1460_m_W       { "K1460_m_W"          , 0.26       };
#     Variable K11400_p_M      { "K11400_p_M"         , 1.403      };
#     Variable K11400_p_W      { "K11400_p_W"         , 0.174      };
#     Variable KK0_0_M         { "KK0_0_M"            , 9.99       };
#     Variable KK0_0_W         { "KK0_0_W"            , 9900000.0  };
#     Variable K_0_M           { "K_0_M"              , 1.717      };
#     Variable K_0_W           { "K_0_W"              , 0.32       };
#     Variable K11270_m_M      { "K11270_m_M"         , 1.272      };
#     Variable K11270_m_W      { "K11270_m_W"         , 0.09       };
#     Variable rho770_0_M      { "rho770_0_M"         , 0.77549    };
#     Variable rho770_0_W      { "rho770_0_W"         , 0.1494     };
#     Variable K_p_M           { "K_p_M"              , 1.717      };
#     Variable K_p_W           { "K_p_W"              , 0.32       };
#     Variable a11260_p_M      { "a11260_p_M"         , 1.23       };
#     Variable a11260_p_W      { "a11260_p_W"         , 0.42       };
#     Variable K892_0_M        { "K892_0_M"           , 0.896      };
#     Variable K892_0_W        { "K892_0_W"           , 0.0503     };
#
#     DK3P_DI.meson_radius = 5;
#     DK3P_DI.particle_masses = {D_0, K_P, K_M, PI_P, PI_M};

# %%
print('\n\n    // Parameters')
print(GooFitChain.make_pars())
# Out:
#     // Parameters
#     Variable D0_radius {"D0_radius", 0.0037559 };
#     Variable a11260p_Spline_Gamma_0 {"a(1)(1260)+::Spline::Gamma::0", 1.58575e-06 };
#     Variable a11260p_Spline_Gamma_1 {"a(1)(1260)+::Spline::Gamma::1", 0.000266091 };
#     Variable a11260p_Spline_Gamma_10 {"a(1)(1260)+::Spline::Gamma::10", 0.0872966 };
#     Variable a11260p_Spline_Gamma_11 {"a(1)(1260)+::Spline::Gamma::11", 0.118951 };
#     Variable a11260p_Spline_Gamma_12 {"a(1)(1260)+::Spline::Gamma::12", 0.161319 };
#     Variable a11260p_Spline_Gamma_13 {"a(1)(1260)+::Spline::Gamma::13", 0.217845 };
#     Variable a11260p_Spline_Gamma_14 {"a(1)(1260)+::Spline::Gamma::14", 0.290854 };
#     Variable a11260p_Spline_Gamma_15 {"a(1)(1260)+::Spline::Gamma::15", 0.377848 };
#     Variable a11260p_Spline_Gamma_16 {"a(1)(1260)+::Spline::Gamma::16", 0.469927 };
#     Variable a11260p_Spline_Gamma_17 {"a(1)(1260)+::Spline::Gamma::17", 0.557264 };
#     Variable a11260p_Spline_Gamma_18 {"a(1)(1260)+::Spline::Gamma::18", 0.634611 };
#     Variable a11260p_Spline_Gamma_19 {"a(1)(1260)+::Spline::Gamma::19", 0.700941 };
#     Variable a11260p_Spline_Gamma_2 {"a(1)(1260)+::Spline::Gamma::2", 0.00139478 };
#     Variable a11260p_Spline_Gamma_20 {"a(1)(1260)+::Spline::Gamma::20", 0.757144 };
#     Variable a11260p_Spline_Gamma_21 {"a(1)(1260)+::Spline::Gamma::21", 0.804628 };
#     Variable a11260p_Spline_Gamma_22 {"a(1)(1260)+::Spline::Gamma::22", 0.844775 };
#     Variable a11260p_Spline_Gamma_23 {"a(1)(1260)+::Spline::Gamma::23", 0.878805 };
#     Variable a11260p_Spline_Gamma_24 {"a(1)(1260)+::Spline::Gamma::24", 0.907767 };
#     Variable a11260p_Spline_Gamma_25 {"a(1)(1260)+::Spline::Gamma::25", 0.932597 };
#     Variable a11260p_Spline_Gamma_26 {"a(1)(1260)+::Spline::Gamma::26", 0.954219 };
#     Variable a11260p_Spline_Gamma_27 {"a(1)(1260)+::Spline::Gamma::27", 0.973428 };
#     Variable a11260p_Spline_Gamma_28 {"a(1)(1260)+::Spline::Gamma::28", 0.990779 };
#     Variable a11260p_Spline_Gamma_29 {"a(1)(1260)+::Spline::Gamma::29", 1.00672 };
#     Variable a11260p_Spline_Gamma_3 {"a(1)(1260)+::Spline::Gamma::3", 0.00376483 };
#     Variable a11260p_Spline_Gamma_30 {"a(1)(1260)+::Spline::Gamma::30", 1.02164 };
#     Variable a11260p_Spline_Gamma_31 {"a(1)(1260)+::Spline::Gamma::31", 1.03585 };
#     Variable a11260p_Spline_Gamma_32 {"a(1)(1260)+::Spline::Gamma::32", 1.04961 };
#     Variable a11260p_Spline_Gamma_33 {"a(1)(1260)+::Spline::Gamma::33", 1.06316 };
#     Variable a11260p_Spline_Gamma_34 {"a(1)(1260)+::Spline::Gamma::34", 1.07665 };
#     Variable a11260p_Spline_Gamma_35 {"a(1)(1260)+::Spline::Gamma::35", 1.09024 };
#     Variable a11260p_Spline_Gamma_36 {"a(1)(1260)+::Spline::Gamma::36", 1.10404 };
#     Variable a11260p_Spline_Gamma_37 {"a(1)(1260)+::Spline::Gamma::37", 1.11815 };
#     Variable a11260p_Spline_Gamma_38 {"a(1)(1260)+::Spline::Gamma::38", 1.13266 };
#     Variable a11260p_Spline_Gamma_39 {"a(1)(1260)+::Spline::Gamma::39", 1.14765 };
#     Variable a11260p_Spline_Gamma_4 {"a(1)(1260)+::Spline::Gamma::4", 0.0076503 };
#     Variable a11260p_Spline_Gamma_5 {"a(1)(1260)+::Spline::Gamma::5", 0.0133309 };
#     Variable a11260p_Spline_Gamma_6 {"a(1)(1260)+::Spline::Gamma::6", 0.0211583 };
#     Variable a11260p_Spline_Gamma_7 {"a(1)(1260)+::Spline::Gamma::7", 0.0316159 };
#     Variable a11260p_Spline_Gamma_8 {"a(1)(1260)+::Spline::Gamma::8", 0.0453899 };
#     Variable a11260p_Spline_Gamma_9 {"a(1)(1260)+::Spline::Gamma::9", 0.0634702 };
#     Variable a11260m_Spline_Gamma_0 {"a(1)(1260)-::Spline::Gamma::0", 1.58575e-06 };
#     Variable a11260m_Spline_Gamma_1 {"a(1)(1260)-::Spline::Gamma::1", 0.000266091 };
#     Variable a11260m_Spline_Gamma_10 {"a(1)(1260)-::Spline::Gamma::10", 0.0872966 };
#     Variable a11260m_Spline_Gamma_11 {"a(1)(1260)-::Spline::Gamma::11", 0.118951 };
#     Variable a11260m_Spline_Gamma_12 {"a(1)(1260)-::Spline::Gamma::12", 0.161319 };
#     Variable a11260m_Spline_Gamma_13 {"a(1)(1260)-::Spline::Gamma::13", 0.217845 };
#     Variable a11260m_Spline_Gamma_14 {"a(1)(1260)-::Spline::Gamma::14", 0.290854 };
#     Variable a11260m_Spline_Gamma_15 {"a(1)(1260)-::Spline::Gamma::15", 0.377848 };
#     Variable a11260m_Spline_Gamma_16 {"a(1)(1260)-::Spline::Gamma::16", 0.469927 };
#     Variable a11260m_Spline_Gamma_17 {"a(1)(1260)-::Spline::Gamma::17", 0.557264 };
#     Variable a11260m_Spline_Gamma_18 {"a(1)(1260)-::Spline::Gamma::18", 0.634611 };
#     Variable a11260m_Spline_Gamma_19 {"a(1)(1260)-::Spline::Gamma::19", 0.700941 };
#     Variable a11260m_Spline_Gamma_2 {"a(1)(1260)-::Spline::Gamma::2", 0.00139478 };
#     Variable a11260m_Spline_Gamma_20 {"a(1)(1260)-::Spline::Gamma::20", 0.757144 };
#     Variable a11260m_Spline_Gamma_21 {"a(1)(1260)-::Spline::Gamma::21", 0.804628 };
#     Variable a11260m_Spline_Gamma_22 {"a(1)(1260)-::Spline::Gamma::22", 0.844775 };
#     Variable a11260m_Spline_Gamma_23 {"a(1)(1260)-::Spline::Gamma::23", 0.878805 };
#     Variable a11260m_Spline_Gamma_24 {"a(1)(1260)-::Spline::Gamma::24", 0.907767 };
#     Variable a11260m_Spline_Gamma_25 {"a(1)(1260)-::Spline::Gamma::25", 0.932597 };
#     Variable a11260m_Spline_Gamma_26 {"a(1)(1260)-::Spline::Gamma::26", 0.954219 };
#     Variable a11260m_Spline_Gamma_27 {"a(1)(1260)-::Spline::Gamma::27", 0.973428 };
#     Variable a11260m_Spline_Gamma_28 {"a(1)(1260)-::Spline::Gamma::28", 0.990779 };
#     Variable a11260m_Spline_Gamma_29 {"a(1)(1260)-::Spline::Gamma::29", 1.00672 };
#     Variable a11260m_Spline_Gamma_3 {"a(1)(1260)-::Spline::Gamma::3", 0.00376483 };
#     Variable a11260m_Spline_Gamma_30 {"a(1)(1260)-::Spline::Gamma::30", 1.02164 };
#     Variable a11260m_Spline_Gamma_31 {"a(1)(1260)-::Spline::Gamma::31", 1.03585 };
#     Variable a11260m_Spline_Gamma_32 {"a(1)(1260)-::Spline::Gamma::32", 1.04961 };
#     Variable a11260m_Spline_Gamma_33 {"a(1)(1260)-::Spline::Gamma::33", 1.06316 };
#     Variable a11260m_Spline_Gamma_34 {"a(1)(1260)-::Spline::Gamma::34", 1.07665 };
#     Variable a11260m_Spline_Gamma_35 {"a(1)(1260)-::Spline::Gamma::35", 1.09024 };
#     Variable a11260m_Spline_Gamma_36 {"a(1)(1260)-::Spline::Gamma::36", 1.10404 };
#     Variable a11260m_Spline_Gamma_37 {"a(1)(1260)-::Spline::Gamma::37", 1.11815 };
#     Variable a11260m_Spline_Gamma_38 {"a(1)(1260)-::Spline::Gamma::38", 1.13266 };
#     Variable a11260m_Spline_Gamma_39 {"a(1)(1260)-::Spline::Gamma::39", 1.14765 };
#     Variable a11260m_Spline_Gamma_4 {"a(1)(1260)-::Spline::Gamma::4", 0.0076503 };
#     Variable a11260m_Spline_Gamma_5 {"a(1)(1260)-::Spline::Gamma::5", 0.0133309 };
#     Variable a11260m_Spline_Gamma_6 {"a(1)(1260)-::Spline::Gamma::6", 0.0211583 };
#     Variable a11260m_Spline_Gamma_7 {"a(1)(1260)-::Spline::Gamma::7", 0.0316159 };
#     Variable a11260m_Spline_Gamma_8 {"a(1)(1260)-::Spline::Gamma::8", 0.0453899 };
#     Variable a11260m_Spline_Gamma_9 {"a(1)(1260)-::Spline::Gamma::9", 0.0634702 };
#     Variable K11270barm_Spline_Gamma_0 {"K(1)(1270)bar-::Spline::Gamma::0", 4.75835e-09 };
#     Variable K11270barm_Spline_Gamma_1 {"K(1)(1270)bar-::Spline::Gamma::1", 5.80294e-05 };
#     Variable K11270barm_Spline_Gamma_10 {"K(1)(1270)bar-::Spline::Gamma::10", 0.151512 };
#     Variable K11270barm_Spline_Gamma_11 {"K(1)(1270)bar-::Spline::Gamma::11", 0.189534 };
#     Variable K11270barm_Spline_Gamma_12 {"K(1)(1270)bar-::Spline::Gamma::12", 0.231993 };
#     Variable K11270barm_Spline_Gamma_13 {"K(1)(1270)bar-::Spline::Gamma::13", 0.28526 };
#     Variable K11270barm_Spline_Gamma_14 {"K(1)(1270)bar-::Spline::Gamma::14", 0.358286 };
#     Variable K11270barm_Spline_Gamma_15 {"K(1)(1270)bar-::Spline::Gamma::15", 0.463362 };
#     Variable K11270barm_Spline_Gamma_16 {"K(1)(1270)bar-::Spline::Gamma::16", 0.61355 };
#     Variable K11270barm_Spline_Gamma_17 {"K(1)(1270)bar-::Spline::Gamma::17", 0.826575 };
#     Variable K11270barm_Spline_Gamma_18 {"K(1)(1270)bar-::Spline::Gamma::18", 1.11348 };
#     Variable K11270barm_Spline_Gamma_19 {"K(1)(1270)bar-::Spline::Gamma::19", 1.34634 };
#     Variable K11270barm_Spline_Gamma_2 {"K(1)(1270)bar-::Spline::Gamma::2", 0.000454221 };
#     Variable K11270barm_Spline_Gamma_20 {"K(1)(1270)bar-::Spline::Gamma::20", 1.55011 };
#     Variable K11270barm_Spline_Gamma_21 {"K(1)(1270)bar-::Spline::Gamma::21", 1.72747 };
#     Variable K11270barm_Spline_Gamma_22 {"K(1)(1270)bar-::Spline::Gamma::22", 1.88093 };
#     Variable K11270barm_Spline_Gamma_23 {"K(1)(1270)bar-::Spline::Gamma::23", 2.01342 };
#     Variable K11270barm_Spline_Gamma_24 {"K(1)(1270)bar-::Spline::Gamma::24", 2.1278 };
#     Variable K11270barm_Spline_Gamma_25 {"K(1)(1270)bar-::Spline::Gamma::25", 2.22662 };
#     Variable K11270barm_Spline_Gamma_26 {"K(1)(1270)bar-::Spline::Gamma::26", 2.31207 };
#     Variable K11270barm_Spline_Gamma_27 {"K(1)(1270)bar-::Spline::Gamma::27", 2.38598 };
#     Variable K11270barm_Spline_Gamma_28 {"K(1)(1270)bar-::Spline::Gamma::28", 2.4499 };
#     Variable K11270barm_Spline_Gamma_29 {"K(1)(1270)bar-::Spline::Gamma::29", 2.50511 };
#     Variable K11270barm_Spline_Gamma_3 {"K(1)(1270)bar-::Spline::Gamma::3", 0.00158376 };
#     Variable K11270barm_Spline_Gamma_30 {"K(1)(1270)bar-::Spline::Gamma::30", 2.5527 };
#     Variable K11270barm_Spline_Gamma_31 {"K(1)(1270)bar-::Spline::Gamma::31", 2.59355 };
#     Variable K11270barm_Spline_Gamma_32 {"K(1)(1270)bar-::Spline::Gamma::32", 2.62844 };
#     Variable K11270barm_Spline_Gamma_33 {"K(1)(1270)bar-::Spline::Gamma::33", 2.65802 };
#     Variable K11270barm_Spline_Gamma_34 {"K(1)(1270)bar-::Spline::Gamma::34", 2.6828 };
#     Variable K11270barm_Spline_Gamma_35 {"K(1)(1270)bar-::Spline::Gamma::35", 2.70334 };
#     Variable K11270barm_Spline_Gamma_36 {"K(1)(1270)bar-::Spline::Gamma::36", 2.71999 };
#     Variable K11270barm_Spline_Gamma_37 {"K(1)(1270)bar-::Spline::Gamma::37", 2.73311 };
#     Variable K11270barm_Spline_Gamma_38 {"K(1)(1270)bar-::Spline::Gamma::38", 2.74303 };
#     Variable K11270barm_Spline_Gamma_39 {"K(1)(1270)bar-::Spline::Gamma::39", 2.75002 };
#     Variable K11270barm_Spline_Gamma_4 {"K(1)(1270)bar-::Spline::Gamma::4", 0.00398346 };
#     Variable K11270barm_Spline_Gamma_5 {"K(1)(1270)bar-::Spline::Gamma::5", 0.0085029 };
#     Variable K11270barm_Spline_Gamma_6 {"K(1)(1270)bar-::Spline::Gamma::6", 0.016814 };
#     Variable K11270barm_Spline_Gamma_7 {"K(1)(1270)bar-::Spline::Gamma::7", 0.0333397 };
#     Variable K11270barm_Spline_Gamma_8 {"K(1)(1270)bar-::Spline::Gamma::8", 0.0686441 };
#     Variable K11270barm_Spline_Gamma_9 {"K(1)(1270)bar-::Spline::Gamma::9", 0.112598 };
#     Variable K11270p_Spline_Gamma_0 {"K(1)(1270)+::Spline::Gamma::0", 4.75835e-09 };
#     Variable K11270p_Spline_Gamma_1 {"K(1)(1270)+::Spline::Gamma::1", 5.80294e-05 };
#     Variable K11270p_Spline_Gamma_10 {"K(1)(1270)+::Spline::Gamma::10", 0.151512 };
#     Variable K11270p_Spline_Gamma_11 {"K(1)(1270)+::Spline::Gamma::11", 0.189534 };
#     Variable K11270p_Spline_Gamma_12 {"K(1)(1270)+::Spline::Gamma::12", 0.231993 };
#     Variable K11270p_Spline_Gamma_13 {"K(1)(1270)+::Spline::Gamma::13", 0.28526 };
#     Variable K11270p_Spline_Gamma_14 {"K(1)(1270)+::Spline::Gamma::14", 0.358286 };
#     Variable K11270p_Spline_Gamma_15 {"K(1)(1270)+::Spline::Gamma::15", 0.463362 };
#     Variable K11270p_Spline_Gamma_16 {"K(1)(1270)+::Spline::Gamma::16", 0.61355 };
#     Variable K11270p_Spline_Gamma_17 {"K(1)(1270)+::Spline::Gamma::17", 0.826575 };
#     Variable K11270p_Spline_Gamma_18 {"K(1)(1270)+::Spline::Gamma::18", 1.11348 };
#     Variable K11270p_Spline_Gamma_19 {"K(1)(1270)+::Spline::Gamma::19", 1.34634 };
#     Variable K11270p_Spline_Gamma_2 {"K(1)(1270)+::Spline::Gamma::2", 0.000454221 };
#     Variable K11270p_Spline_Gamma_20 {"K(1)(1270)+::Spline::Gamma::20", 1.55011 };
#     Variable K11270p_Spline_Gamma_21 {"K(1)(1270)+::Spline::Gamma::21", 1.72747 };
#     Variable K11270p_Spline_Gamma_22 {"K(1)(1270)+::Spline::Gamma::22", 1.88093 };
#     Variable K11270p_Spline_Gamma_23 {"K(1)(1270)+::Spline::Gamma::23", 2.01342 };
#     Variable K11270p_Spline_Gamma_24 {"K(1)(1270)+::Spline::Gamma::24", 2.1278 };
#     Variable K11270p_Spline_Gamma_25 {"K(1)(1270)+::Spline::Gamma::25", 2.22662 };
#     Variable K11270p_Spline_Gamma_26 {"K(1)(1270)+::Spline::Gamma::26", 2.31207 };
#     Variable K11270p_Spline_Gamma_27 {"K(1)(1270)+::Spline::Gamma::27", 2.38598 };
#     Variable K11270p_Spline_Gamma_28 {"K(1)(1270)+::Spline::Gamma::28", 2.4499 };
#     Variable K11270p_Spline_Gamma_29 {"K(1)(1270)+::Spline::Gamma::29", 2.50511 };
#     Variable K11270p_Spline_Gamma_3 {"K(1)(1270)+::Spline::Gamma::3", 0.00158376 };
#     Variable K11270p_Spline_Gamma_30 {"K(1)(1270)+::Spline::Gamma::30", 2.5527 };
#     Variable K11270p_Spline_Gamma_31 {"K(1)(1270)+::Spline::Gamma::31", 2.59355 };
#     Variable K11270p_Spline_Gamma_32 {"K(1)(1270)+::Spline::Gamma::32", 2.62844 };
#     Variable K11270p_Spline_Gamma_33 {"K(1)(1270)+::Spline::Gamma::33", 2.65802 };
#     Variable K11270p_Spline_Gamma_34 {"K(1)(1270)+::Spline::Gamma::34", 2.6828 };
#     Variable K11270p_Spline_Gamma_35 {"K(1)(1270)+::Spline::Gamma::35", 2.70334 };
#     Variable K11270p_Spline_Gamma_36 {"K(1)(1270)+::Spline::Gamma::36", 2.71999 };
#     Variable K11270p_Spline_Gamma_37 {"K(1)(1270)+::Spline::Gamma::37", 2.73311 };
#     Variable K11270p_Spline_Gamma_38 {"K(1)(1270)+::Spline::Gamma::38", 2.74303 };
#     Variable K11270p_Spline_Gamma_39 {"K(1)(1270)+::Spline::Gamma::39", 2.75002 };
#     Variable K11270p_Spline_Gamma_4 {"K(1)(1270)+::Spline::Gamma::4", 0.00398346 };
#     Variable K11270p_Spline_Gamma_5 {"K(1)(1270)+::Spline::Gamma::5", 0.0085029 };
#     Variable K11270p_Spline_Gamma_6 {"K(1)(1270)+::Spline::Gamma::6", 0.016814 };
#     Variable K11270p_Spline_Gamma_7 {"K(1)(1270)+::Spline::Gamma::7", 0.0333397 };
#     Variable K11270p_Spline_Gamma_8 {"K(1)(1270)+::Spline::Gamma::8", 0.0686441 };
#     Variable K11270p_Spline_Gamma_9 {"K(1)(1270)+::Spline::Gamma::9", 0.112598 };
#     Variable K1460barm_Spline_Gamma_0 {"K(1460)bar-::Spline::Gamma::0", 3.62761e-06 };
#     Variable K1460barm_Spline_Gamma_1 {"K(1460)bar-::Spline::Gamma::1", 0.00199783 };
#     Variable K1460barm_Spline_Gamma_10 {"K(1460)bar-::Spline::Gamma::10", 0.0985144 };
#     Variable K1460barm_Spline_Gamma_11 {"K(1460)bar-::Spline::Gamma::11", 0.126628 };
#     Variable K1460barm_Spline_Gamma_12 {"K(1460)bar-::Spline::Gamma::12", 0.159151 };
#     Variable K1460barm_Spline_Gamma_13 {"K(1460)bar-::Spline::Gamma::13", 0.195279 };
#     Variable K1460barm_Spline_Gamma_14 {"K(1460)bar-::Spline::Gamma::14", 0.234274 };
#     Variable K1460barm_Spline_Gamma_15 {"K(1460)bar-::Spline::Gamma::15", 0.275466 };
#     Variable K1460barm_Spline_Gamma_16 {"K(1460)bar-::Spline::Gamma::16", 0.318253 };
#     Variable K1460barm_Spline_Gamma_17 {"K(1460)bar-::Spline::Gamma::17", 0.362108 };
#     Variable K1460barm_Spline_Gamma_18 {"K(1460)bar-::Spline::Gamma::18", 0.406587 };
#     Variable K1460barm_Spline_Gamma_19 {"K(1460)bar-::Spline::Gamma::19", 0.451339 };
#     Variable K1460barm_Spline_Gamma_2 {"K(1460)bar-::Spline::Gamma::2", 0.00731765 };
#     Variable K1460barm_Spline_Gamma_20 {"K(1460)bar-::Spline::Gamma::20", 0.496132 };
#     Variable K1460barm_Spline_Gamma_21 {"K(1460)bar-::Spline::Gamma::21", 0.540891 };
#     Variable K1460barm_Spline_Gamma_22 {"K(1460)bar-::Spline::Gamma::22", 0.585768 };
#     Variable K1460barm_Spline_Gamma_23 {"K(1460)bar-::Spline::Gamma::23", 0.631244 };
#     Variable K1460barm_Spline_Gamma_24 {"K(1460)bar-::Spline::Gamma::24", 0.6783 };
#     Variable K1460barm_Spline_Gamma_25 {"K(1460)bar-::Spline::Gamma::25", 0.72859 };
#     Variable K1460barm_Spline_Gamma_26 {"K(1460)bar-::Spline::Gamma::26", 0.784086 };
#     Variable K1460barm_Spline_Gamma_27 {"K(1460)bar-::Spline::Gamma::27", 0.839021 };
#     Variable K1460barm_Spline_Gamma_28 {"K(1460)bar-::Spline::Gamma::28", 0.886293 };
#     Variable K1460barm_Spline_Gamma_29 {"K(1460)bar-::Spline::Gamma::29", 0.934222 };
#     Variable K1460barm_Spline_Gamma_3 {"K(1460)bar-::Spline::Gamma::3", 0.014665 };
#     Variable K1460barm_Spline_Gamma_30 {"K(1460)bar-::Spline::Gamma::30", 0.985332 };
#     Variable K1460barm_Spline_Gamma_31 {"K(1460)bar-::Spline::Gamma::31", 1.04076 };
#     Variable K1460barm_Spline_Gamma_32 {"K(1460)bar-::Spline::Gamma::32", 1.10118 };
#     Variable K1460barm_Spline_Gamma_33 {"K(1460)bar-::Spline::Gamma::33", 1.16476 };
#     Variable K1460barm_Spline_Gamma_34 {"K(1460)bar-::Spline::Gamma::34", 1.2286 };
#     Variable K1460barm_Spline_Gamma_35 {"K(1460)bar-::Spline::Gamma::35", 1.29296 };
#     Variable K1460barm_Spline_Gamma_36 {"K(1460)bar-::Spline::Gamma::36", 1.35787 };
#     Variable K1460barm_Spline_Gamma_37 {"K(1460)bar-::Spline::Gamma::37", 1.42323 };
#     Variable K1460barm_Spline_Gamma_38 {"K(1460)bar-::Spline::Gamma::38", 1.48885 };
#     Variable K1460barm_Spline_Gamma_39 {"K(1460)bar-::Spline::Gamma::39", 1.55441 };
#     Variable K1460barm_Spline_Gamma_4 {"K(1460)bar-::Spline::Gamma::4", 0.0227802 };
#     Variable K1460barm_Spline_Gamma_5 {"K(1460)bar-::Spline::Gamma::5", 0.0309861 };
#     Variable K1460barm_Spline_Gamma_6 {"K(1460)bar-::Spline::Gamma::6", 0.0391908 };
#     Variable K1460barm_Spline_Gamma_7 {"K(1460)bar-::Spline::Gamma::7", 0.0479023 };
#     Variable K1460barm_Spline_Gamma_8 {"K(1460)bar-::Spline::Gamma::8", 0.0589914 };
#     Variable K1460barm_Spline_Gamma_9 {"K(1460)bar-::Spline::Gamma::9", 0.0756823 };
#     Variable K1460p_Spline_Gamma_0 {"K(1460)+::Spline::Gamma::0", 3.62761e-06 };
#     Variable K1460p_Spline_Gamma_1 {"K(1460)+::Spline::Gamma::1", 0.00199783 };
#     Variable K1460p_Spline_Gamma_10 {"K(1460)+::Spline::Gamma::10", 0.0985144 };
#     Variable K1460p_Spline_Gamma_11 {"K(1460)+::Spline::Gamma::11", 0.126628 };
#     Variable K1460p_Spline_Gamma_12 {"K(1460)+::Spline::Gamma::12", 0.159151 };
#     Variable K1460p_Spline_Gamma_13 {"K(1460)+::Spline::Gamma::13", 0.195279 };
#     Variable K1460p_Spline_Gamma_14 {"K(1460)+::Spline::Gamma::14", 0.234274 };
#     Variable K1460p_Spline_Gamma_15 {"K(1460)+::Spline::Gamma::15", 0.275466 };
#     Variable K1460p_Spline_Gamma_16 {"K(1460)+::Spline::Gamma::16", 0.318253 };
#     Variable K1460p_Spline_Gamma_17 {"K(1460)+::Spline::Gamma::17", 0.362108 };
#     Variable K1460p_Spline_Gamma_18 {"K(1460)+::Spline::Gamma::18", 0.406587 };
#     Variable K1460p_Spline_Gamma_19 {"K(1460)+::Spline::Gamma::19", 0.451339 };
#     Variable K1460p_Spline_Gamma_2 {"K(1460)+::Spline::Gamma::2", 0.00731765 };
#     Variable K1460p_Spline_Gamma_20 {"K(1460)+::Spline::Gamma::20", 0.496132 };
#     Variable K1460p_Spline_Gamma_21 {"K(1460)+::Spline::Gamma::21", 0.540891 };
#     Variable K1460p_Spline_Gamma_22 {"K(1460)+::Spline::Gamma::22", 0.585768 };
#     Variable K1460p_Spline_Gamma_23 {"K(1460)+::Spline::Gamma::23", 0.631244 };
#     Variable K1460p_Spline_Gamma_24 {"K(1460)+::Spline::Gamma::24", 0.6783 };
#     Variable K1460p_Spline_Gamma_25 {"K(1460)+::Spline::Gamma::25", 0.72859 };
#     Variable K1460p_Spline_Gamma_26 {"K(1460)+::Spline::Gamma::26", 0.784086 };
#     Variable K1460p_Spline_Gamma_27 {"K(1460)+::Spline::Gamma::27", 0.839021 };
#     Variable K1460p_Spline_Gamma_28 {"K(1460)+::Spline::Gamma::28", 0.886293 };
#     Variable K1460p_Spline_Gamma_29 {"K(1460)+::Spline::Gamma::29", 0.934222 };
#     Variable K1460p_Spline_Gamma_3 {"K(1460)+::Spline::Gamma::3", 0.014665 };
#     Variable K1460p_Spline_Gamma_30 {"K(1460)+::Spline::Gamma::30", 0.985332 };
#     Variable K1460p_Spline_Gamma_31 {"K(1460)+::Spline::Gamma::31", 1.04076 };
#     Variable K1460p_Spline_Gamma_32 {"K(1460)+::Spline::Gamma::32", 1.10118 };
#     Variable K1460p_Spline_Gamma_33 {"K(1460)+::Spline::Gamma::33", 1.16476 };
#     Variable K1460p_Spline_Gamma_34 {"K(1460)+::Spline::Gamma::34", 1.2286 };
#     Variable K1460p_Spline_Gamma_35 {"K(1460)+::Spline::Gamma::35", 1.29296 };
#     Variable K1460p_Spline_Gamma_36 {"K(1460)+::Spline::Gamma::36", 1.35787 };
#     Variable K1460p_Spline_Gamma_37 {"K(1460)+::Spline::Gamma::37", 1.42323 };
#     Variable K1460p_Spline_Gamma_38 {"K(1460)+::Spline::Gamma::38", 1.48885 };
#     Variable K1460p_Spline_Gamma_39 {"K(1460)+::Spline::Gamma::39", 1.55441 };
#     Variable K1460p_Spline_Gamma_4 {"K(1460)+::Spline::Gamma::4", 0.0227802 };
#     Variable K1460p_Spline_Gamma_5 {"K(1460)+::Spline::Gamma::5", 0.0309861 };
#     Variable K1460p_Spline_Gamma_6 {"K(1460)+::Spline::Gamma::6", 0.0391908 };
#     Variable K1460p_Spline_Gamma_7 {"K(1460)+::Spline::Gamma::7", 0.0479023 };
#     Variable K1460p_Spline_Gamma_8 {"K(1460)+::Spline::Gamma::8", 0.0589914 };
#     Variable K1460p_Spline_Gamma_9 {"K(1460)+::Spline::Gamma::9", 0.0756823 };
#     Variable f_scatt0 {"f_scatt0", 0.23399 };
#     Variable f_scatt1 {"f_scatt1", 0.15044 };
#     Variable f_scatt2 {"f_scatt2", -0.20545 };
#     Variable f_scatt3 {"f_scatt3", 0.32825 };
#     Variable f_scatt4 {"f_scatt4", 0.35412 };
#     Variable IS_p1_4pi {"IS_p1_4pi", 0 };
#     Variable IS_p1_EtaEta {"IS_p1_EtaEta", -0.39899 };
#     Variable IS_p1_EtapEta {"IS_p1_EtapEta", -0.34639 };
#     Variable IS_p1_KK {"IS_p1_KK", -0.55377 };
#     Variable IS_p1_mass {"IS_p1_mass", 0.651 };
#     Variable IS_p1_pipi {"IS_p1_pipi", 0.22889 };
#     Variable IS_p2_4pi {"IS_p2_4pi", 0 };
#     Variable IS_p2_EtaEta {"IS_p2_EtaEta", 0.39065 };
#     Variable IS_p2_EtapEta {"IS_p2_EtapEta", 0.31503 };
#     Variable IS_p2_KK {"IS_p2_KK", 0.55095 };
#     Variable IS_p2_mass {"IS_p2_mass", 1.2036 };
#     Variable IS_p2_pipi {"IS_p2_pipi", 0.94128 };
#     Variable IS_p3_4pi {"IS_p3_4pi", 0.55639 };
#     Variable IS_p3_EtaEta {"IS_p3_EtaEta", 0.1834 };
#     Variable IS_p3_EtapEta {"IS_p3_EtapEta", 0.18681 };
#     Variable IS_p3_KK {"IS_p3_KK", 0.23888 };
#     Variable IS_p3_mass {"IS_p3_mass", 1.55817 };
#     Variable IS_p3_pipi {"IS_p3_pipi", 0.36856 };
#     Variable IS_p4_4pi {"IS_p4_4pi", 0.85679 };
#     Variable IS_p4_EtaEta {"IS_p4_EtaEta", 0.19906 };
#     Variable IS_p4_EtapEta {"IS_p4_EtapEta", -0.00984 };
#     Variable IS_p4_KK {"IS_p4_KK", 0.40907 };
#     Variable IS_p4_mass {"IS_p4_mass", 1.21 };
#     Variable IS_p4_pipi {"IS_p4_pipi", 0.3365 };
#     Variable IS_p5_4pi {"IS_p5_4pi", -0.79658 };
#     Variable IS_p5_EtaEta {"IS_p5_EtaEta", -0.00355 };
#     Variable IS_p5_EtapEta {"IS_p5_EtapEta", 0.22358 };
#     Variable IS_p5_KK {"IS_p5_KK", -0.17558 };
#     Variable IS_p5_mass {"IS_p5_mass", 1.82206 };
#     Variable IS_p5_pipi {"IS_p5_pipi", 0.18171 };
#     Variable s0_prod {"s0_prod", -1 };
#     Variable s0_scatt {"s0_scatt", -3.92637 };
#     Variable sA {"sA", 1 };
#     Variable sA0 {"sA0", -0.15 };
#     Variable K11270p_mass {"K(1)(1270)+_mass", 1287.43 };
#     Variable K11270p_radius {"K(1)(1270)+_radius", 0.0017 };
#     Variable K11270p_width {"K(1)(1270)+_width", 94.15 };
#     Variable K11270barm_mass {"K(1)(1270)bar-_mass", 1287.43 };
#     Variable K11270barm_radius {"K(1)(1270)bar-_radius", 0.0017 };
#     Variable K11270barm_width {"K(1)(1270)bar-_width", 94.15 };
#     Variable K1460p_mass {"K(1460)+_mass", 1540.76 };
#     Variable K1460p_radius {"K(1460)+_radius", 0.0017 };
#     Variable K1460p_width {"K(1460)+_width", 364.13 };
#     Variable K1460barm_mass {"K(1460)bar-_mass", 1540.76 };
#     Variable K1460barm_radius {"K(1460)bar-_radius", 0.0017 };
#     Variable K1460barm_width {"K(1460)bar-_width", 364.13 };
#     Variable a11260p_mass {"a(1)(1260)+_mass", 1190.84 };
#     Variable a11260p_radius {"a(1)(1260)+_radius", 0.0017 };
#     Variable a11260p_width {"a(1)(1260)+_width", 437.43 };
#     Variable a11260m_mass {"a(1)(1260)-_mass", 1190.84 };
#     Variable a11260m_radius {"a(1)(1260)-_radius", 0.0017 };
#     Variable a11260m_width {"a(1)(1260)-_width", 437.43 };
#
#     std::vector<Variable> K1460barm_SplineArr {{
#         K1460barm_Spline_Gamma_0,
#         K1460barm_Spline_Gamma_1,
#         K1460barm_Spline_Gamma_2,
#         K1460barm_Spline_Gamma_3,
#         K1460barm_Spline_Gamma_4,
#         K1460barm_Spline_Gamma_5,
#         K1460barm_Spline_Gamma_6,
#         K1460barm_Spline_Gamma_7,
#         K1460barm_Spline_Gamma_8,
#         K1460barm_Spline_Gamma_9,
#         K1460barm_Spline_Gamma_10,
#         K1460barm_Spline_Gamma_11,
#         K1460barm_Spline_Gamma_12,
#         K1460barm_Spline_Gamma_13,
#         K1460barm_Spline_Gamma_14,
#         K1460barm_Spline_Gamma_15,
#         K1460barm_Spline_Gamma_16,
#         K1460barm_Spline_Gamma_17,
#         K1460barm_Spline_Gamma_18,
#         K1460barm_Spline_Gamma_19,
#         K1460barm_Spline_Gamma_20,
#         K1460barm_Spline_Gamma_21,
#         K1460barm_Spline_Gamma_22,
#         K1460barm_Spline_Gamma_23,
#         K1460barm_Spline_Gamma_24,
#         K1460barm_Spline_Gamma_25,
#         K1460barm_Spline_Gamma_26,
#         K1460barm_Spline_Gamma_27,
#         K1460barm_Spline_Gamma_28,
#         K1460barm_Spline_Gamma_29,
#         K1460barm_Spline_Gamma_30,
#         K1460barm_Spline_Gamma_31,
#         K1460barm_Spline_Gamma_32,
#         K1460barm_Spline_Gamma_33,
#         K1460barm_Spline_Gamma_34,
#         K1460barm_Spline_Gamma_35,
#         K1460barm_Spline_Gamma_36,
#         K1460barm_Spline_Gamma_37,
#         K1460barm_Spline_Gamma_38,
#         K1460barm_Spline_Gamma_39
#     }};
#
#     std::vector<Variable> a11260m_SplineArr {{
#         a11260m_Spline_Gamma_0,
#         a11260m_Spline_Gamma_1,
#         a11260m_Spline_Gamma_2,
#         a11260m_Spline_Gamma_3,
#         a11260m_Spline_Gamma_4,
#         a11260m_Spline_Gamma_5,
#         a11260m_Spline_Gamma_6,
#         a11260m_Spline_Gamma_7,
#         a11260m_Spline_Gamma_8,
#         a11260m_Spline_Gamma_9,
#         a11260m_Spline_Gamma_10,
#         a11260m_Spline_Gamma_11,
#         a11260m_Spline_Gamma_12,
#         a11260m_Spline_Gamma_13,
#         a11260m_Spline_Gamma_14,
#         a11260m_Spline_Gamma_15,
#         a11260m_Spline_Gamma_16,
#         a11260m_Spline_Gamma_17,
#         a11260m_Spline_Gamma_18,
#         a11260m_Spline_Gamma_19,
#         a11260m_Spline_Gamma_20,
#         a11260m_Spline_Gamma_21,
#         a11260m_Spline_Gamma_22,
#         a11260m_Spline_Gamma_23,
#         a11260m_Spline_Gamma_24,
#         a11260m_Spline_Gamma_25,
#         a11260m_Spline_Gamma_26,
#         a11260m_Spline_Gamma_27,
#         a11260m_Spline_Gamma_28,
#         a11260m_Spline_Gamma_29,
#         a11260m_Spline_Gamma_30,
#         a11260m_Spline_Gamma_31,
#         a11260m_Spline_Gamma_32,
#         a11260m_Spline_Gamma_33,
#         a11260m_Spline_Gamma_34,
#         a11260m_Spline_Gamma_35,
#         a11260m_Spline_Gamma_36,
#         a11260m_Spline_Gamma_37,
#         a11260m_Spline_Gamma_38,
#         a11260m_Spline_Gamma_39
#     }};
#
#     std::vector<Variable> K11270barm_SplineArr {{
#         K11270barm_Spline_Gamma_0,
#         K11270barm_Spline_Gamma_1,
#         K11270barm_Spline_Gamma_2,
#         K11270barm_Spline_Gamma_3,
#         K11270barm_Spline_Gamma_4,
#         K11270barm_Spline_Gamma_5,
#         K11270barm_Spline_Gamma_6,
#         K11270barm_Spline_Gamma_7,
#         K11270barm_Spline_Gamma_8,
#         K11270barm_Spline_Gamma_9,
#         K11270barm_Spline_Gamma_10,
#         K11270barm_Spline_Gamma_11,
#         K11270barm_Spline_Gamma_12,
#         K11270barm_Spline_Gamma_13,
#         K11270barm_Spline_Gamma_14,
#         K11270barm_Spline_Gamma_15,
#         K11270barm_Spline_Gamma_16,
#         K11270barm_Spline_Gamma_17,
#         K11270barm_Spline_Gamma_18,
#         K11270barm_Spline_Gamma_19,
#         K11270barm_Spline_Gamma_20,
#         K11270barm_Spline_Gamma_21,
#         K11270barm_Spline_Gamma_22,
#         K11270barm_Spline_Gamma_23,
#         K11270barm_Spline_Gamma_24,
#         K11270barm_Spline_Gamma_25,
#         K11270barm_Spline_Gamma_26,
#         K11270barm_Spline_Gamma_27,
#         K11270barm_Spline_Gamma_28,
#         K11270barm_Spline_Gamma_29,
#         K11270barm_Spline_Gamma_30,
#         K11270barm_Spline_Gamma_31,
#         K11270barm_Spline_Gamma_32,
#         K11270barm_Spline_Gamma_33,
#         K11270barm_Spline_Gamma_34,
#         K11270barm_Spline_Gamma_35,
#         K11270barm_Spline_Gamma_36,
#         K11270barm_Spline_Gamma_37,
#         K11270barm_Spline_Gamma_38,
#         K11270barm_Spline_Gamma_39
#     }};
#
#     std::vector<Variable> a11260p_SplineArr {{
#         a11260p_Spline_Gamma_0,
#         a11260p_Spline_Gamma_1,
#         a11260p_Spline_Gamma_2,
#         a11260p_Spline_Gamma_3,
#         a11260p_Spline_Gamma_4,
#         a11260p_Spline_Gamma_5,
#         a11260p_Spline_Gamma_6,
#         a11260p_Spline_Gamma_7,
#         a11260p_Spline_Gamma_8,
#         a11260p_Spline_Gamma_9,
#         a11260p_Spline_Gamma_10,
#         a11260p_Spline_Gamma_11,
#         a11260p_Spline_Gamma_12,
#         a11260p_Spline_Gamma_13,
#         a11260p_Spline_Gamma_14,
#         a11260p_Spline_Gamma_15,
#         a11260p_Spline_Gamma_16,
#         a11260p_Spline_Gamma_17,
#         a11260p_Spline_Gamma_18,
#         a11260p_Spline_Gamma_19,
#         a11260p_Spline_Gamma_20,
#         a11260p_Spline_Gamma_21,
#         a11260p_Spline_Gamma_22,
#         a11260p_Spline_Gamma_23,
#         a11260p_Spline_Gamma_24,
#         a11260p_Spline_Gamma_25,
#         a11260p_Spline_Gamma_26,
#         a11260p_Spline_Gamma_27,
#         a11260p_Spline_Gamma_28,
#         a11260p_Spline_Gamma_29,
#         a11260p_Spline_Gamma_30,
#         a11260p_Spline_Gamma_31,
#         a11260p_Spline_Gamma_32,
#         a11260p_Spline_Gamma_33,
#         a11260p_Spline_Gamma_34,
#         a11260p_Spline_Gamma_35,
#         a11260p_Spline_Gamma_36,
#         a11260p_Spline_Gamma_37,
#         a11260p_Spline_Gamma_38,
#         a11260p_Spline_Gamma_39
#     }};
#
#     std::vector<Variable> K1460p_SplineArr {{
#         K1460p_Spline_Gamma_0,
#         K1460p_Spline_Gamma_1,
#         K1460p_Spline_Gamma_2,
#         K1460p_Spline_Gamma_3,
#         K1460p_Spline_Gamma_4,
#         K1460p_Spline_Gamma_5,
#         K1460p_Spline_Gamma_6,
#         K1460p_Spline_Gamma_7,
#         K1460p_Spline_Gamma_8,
#         K1460p_Spline_Gamma_9,
#         K1460p_Spline_Gamma_10,
#         K1460p_Spline_Gamma_11,
#         K1460p_Spline_Gamma_12,
#         K1460p_Spline_Gamma_13,
#         K1460p_Spline_Gamma_14,
#         K1460p_Spline_Gamma_15,
#         K1460p_Spline_Gamma_16,
#         K1460p_Spline_Gamma_17,
#         K1460p_Spline_Gamma_18,
#         K1460p_Spline_Gamma_19,
#         K1460p_Spline_Gamma_20,
#         K1460p_Spline_Gamma_21,
#         K1460p_Spline_Gamma_22,
#         K1460p_Spline_Gamma_23,
#         K1460p_Spline_Gamma_24,
#         K1460p_Spline_Gamma_25,
#         K1460p_Spline_Gamma_26,
#         K1460p_Spline_Gamma_27,
#         K1460p_Spline_Gamma_28,
#         K1460p_Spline_Gamma_29,
#         K1460p_Spline_Gamma_30,
#         K1460p_Spline_Gamma_31,
#         K1460p_Spline_Gamma_32,
#         K1460p_Spline_Gamma_33,
#         K1460p_Spline_Gamma_34,
#         K1460p_Spline_Gamma_35,
#         K1460p_Spline_Gamma_36,
#         K1460p_Spline_Gamma_37,
#         K1460p_Spline_Gamma_38,
#         K1460p_Spline_Gamma_39
#     }};
#
#     std::vector<Variable> K11270p_SplineArr {{
#         K11270p_Spline_Gamma_0,
#         K11270p_Spline_Gamma_1,
#         K11270p_Spline_Gamma_2,
#         K11270p_Spline_Gamma_3,
#         K11270p_Spline_Gamma_4,
#         K11270p_Spline_Gamma_5,
#         K11270p_Spline_Gamma_6,
#         K11270p_Spline_Gamma_7,
#         K11270p_Spline_Gamma_8,
#         K11270p_Spline_Gamma_9,
#         K11270p_Spline_Gamma_10,
#         K11270p_Spline_Gamma_11,
#         K11270p_Spline_Gamma_12,
#         K11270p_Spline_Gamma_13,
#         K11270p_Spline_Gamma_14,
#         K11270p_Spline_Gamma_15,
#         K11270p_Spline_Gamma_16,
#         K11270p_Spline_Gamma_17,
#         K11270p_Spline_Gamma_18,
#         K11270p_Spline_Gamma_19,
#         K11270p_Spline_Gamma_20,
#         K11270p_Spline_Gamma_21,
#         K11270p_Spline_Gamma_22,
#         K11270p_Spline_Gamma_23,
#         K11270p_Spline_Gamma_24,
#         K11270p_Spline_Gamma_25,
#         K11270p_Spline_Gamma_26,
#         K11270p_Spline_Gamma_27,
#         K11270p_Spline_Gamma_28,
#         K11270p_Spline_Gamma_29,
#         K11270p_Spline_Gamma_30,
#         K11270p_Spline_Gamma_31,
#         K11270p_Spline_Gamma_32,
#         K11270p_Spline_Gamma_33,
#         K11270p_Spline_Gamma_34,
#         K11270p_Spline_Gamma_35,
#         K11270p_Spline_Gamma_36,
#         K11270p_Spline_Gamma_37,
#         K11270p_Spline_Gamma_38,
#         K11270p_Spline_Gamma_39
#     }};
#
#     std::array<Variable, 5> f_scatt {{
#         f_scatt0,
#         f_scatt1,
#         f_scatt2,
#         f_scatt3,
#         f_scatt4
#     }};
#
#     std::array<Variable, 5*6> IS_poles {{
#         IS_p1_pipi,
#         IS_p1_KK,
#         IS_p1_4pi,
#         IS_p1_EtaEta,
#         IS_p1_EtapEta,
#         IS_p1_mass,
#         IS_p2_pipi,
#         IS_p2_KK,
#         IS_p2_4pi,
#         IS_p2_EtaEta,
#         IS_p2_EtapEta,
#         IS_p2_mass,
#         IS_p3_pipi,
#         IS_p3_KK,
#         IS_p3_4pi,
#         IS_p3_EtaEta,
#         IS_p3_EtapEta,
#         IS_p3_mass,
#         IS_p4_pipi,
#         IS_p4_KK,
#         IS_p4_4pi,
#         IS_p4_EtaEta,
#         IS_p4_EtapEta,
#         IS_p4_mass,
#         IS_p5_pipi,
#         IS_p5_KK,
#         IS_p5_4pi,
#         IS_p5_EtaEta,
#         IS_p5_EtapEta,
#         IS_p5_mass
#     }};

# %% [markdown]
# ### And the lines can be turned into code, as well:

# %%
print('\n\n    // Lines')
for n, line in enumerate(lines):
    print('    // Line', n)
    print(line.to_goofit(all_states[1:]), end='\n\n\n')
# Out:
#     // Lines
#     // Line 0
#     // D0[S]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}
#
#     spin_factor_list.push_back(std::vector<SpinFactor*>({
#         new SpinFactor("SF", SF_4Body::DtoV1V2_V1toP1P2_V2toP3P4_S          , 0, 1, 2, 3)
#     }));
#
#     line_factor_list.push_back(std::vector<Lineshape*>{
#         new Lineshapes::RBW("phi(1020)0", phi1020_0_M, phi1020_0_W, 1, M_12, FF::BL2),
#         new Lineshapes::RBW("rho(770)0", rho770_0_M, rho770_0_W, 1, M_12, FF::BL2)
#     });
#
#     amplitudes_list.push_back(new Amplitude{
#         "D0[S]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}",
#         mkvar("D0[S]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}_r", true, 1.0, 0.0),
#         mkvar("D0[S]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}_i", true, 0.0, 0.1),
#         line_factor_list.back(),
#         spin_factor_list.back(),
#         1});
#
#     DK3P_DI.amplitudes_B.push_back(amplitudes_list.back());
#
#
#     // Line 1
#     // D0[P]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}
#
#     spin_factor_list.push_back(std::vector<SpinFactor*>({
#         new SpinFactor("SF", SF_4Body::DtoV1V2_V1toP1P2_V2toP3P4_P          , 0, 1, 2, 3),
#         new SpinFactor("SF", SF_4Body::FF_12_34_L1                          , 0, 1, 2, 3)
#     }));
#
#     line_factor_list.push_back(std::vector<Lineshape*>{
#         new Lineshapes::RBW("phi(1020)0", phi1020_0_M, phi1020_0_W, 1, M_12, FF::BL2),
#         new Lineshapes::RBW("rho(770)0", rho770_0_M, rho770_0_W, 1, M_12, FF::BL2)
#     });
#
#     amplitudes_list.push_back(new Amplitude{
#         "D0[P]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}",
#         mkvar("D0[P]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}_r", false, 0.459265, 0.323015),
#         mkvar("D0[P]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}_i", false, 0.323015, 0.0108665),
#         line_factor_list.back(),
#         spin_factor_list.back(),
#         1});
#
#     DK3P_DI.amplitudes_B.push_back(amplitudes_list.back());
#
#
#     // Line 2
#     // D0[D]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}
#
#     spin_factor_list.push_back(std::vector<SpinFactor*>({
#         new SpinFactor("SF", SF_4Body::DtoV1V2_V1toP1P2_V2toP3P4_D          , 0, 1, 2, 3),
#         new SpinFactor("SF", SF_4Body::FF_12_34_L2                          , 0, 1, 2, 3)
#     }));
#
#     line_factor_list.push_back(std::vector<Lineshape*>{
#         new Lineshapes::RBW("phi(1020)0", phi1020_0_M, phi1020_0_W, 1, M_12, FF::BL2),
#         new Lineshapes::RBW("rho(770)0", rho770_0_M, rho770_0_W, 1, M_12, FF::BL2)
#     });
#
#     amplitudes_list.push_back(new Amplitude{
#         "D0[D]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}",
#         mkvar("D0[D]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}_r", false, 1.54426, 1.33181),
#         mkvar("D0[D]{phi(1020)0{K+,K-},rho(770)0{pi+,pi-}}_i", false, 1.33181, 0.0473418),
#         line_factor_list.back(),
#         spin_factor_list.back(),
#         1});
#
#     DK3P_DI.amplitudes_B.push_back(amplitudes_list.back());
#
#
#     // Line 3
#     // D0[S]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}
#
#     spin_factor_list.push_back(std::vector<SpinFactor*>({
#         new SpinFactor("SF", SF_4Body::DtoV1V2_V1toP1P2_V2toP3P4_S          , 0, 3, 1, 2)
#     }));
#
#     line_factor_list.push_back(std::vector<Lineshape*>{
#         new Lineshapes::RBW("K*(892)0", K892_0_M, K892_0_W, 1, M_14, FF::BL2),
#         new Lineshapes::RBW("K*(892)bar0", K892_0_M, K892_0_W, 1, M_14, FF::BL2)
#     });
#
#     amplitudes_list.push_back(new Amplitude{
#         "D0[S]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}",
#         mkvar("D0[S]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}_r", false, 0.20988, -0.0797069),
#         mkvar("D0[S]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}_i", false, -0.0797069, 0.00350462),
#         line_factor_list.back(),
#         spin_factor_list.back(),
#         1});
#
#     DK3P_DI.amplitudes_B.push_back(amplitudes_list.back());
#
#
#     // Line 4
#     // D0[P]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}
#
#     spin_factor_list.push_back(std::vector<SpinFactor*>({
#         new SpinFactor("SF", SF_4Body::DtoV1V2_V1toP1P2_V2toP3P4_P          , 0, 3, 1, 2),
#         new SpinFactor("SF", SF_4Body::FF_12_34_L1                          , 0, 3, 1, 2)
#     }));
#
#     line_factor_list.push_back(std::vector<Lineshape*>{
#         new Lineshapes::RBW("K*(892)0", K892_0_M, K892_0_W, 1, M_14, FF::BL2),
#         new Lineshapes::RBW("K*(892)bar0", K892_0_M, K892_0_W, 1, M_14, FF::BL2)
#     });
#
#     amplitudes_list.push_back(new Amplitude{
#         "D0[P]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}",
#         mkvar("D0[P]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}_r", false, 0.113319, 0.381286),
#         mkvar("D0[P]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}_i", false, 0.381286, 0.00560611),
#         line_factor_list.back(),
#         spin_factor_list.back(),
#         1});
#
#     DK3P_DI.amplitudes_B.push_back(amplitudes_list.back());
#
#
#     // Line 5
#     // D0[D]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}
#
#     spin_factor_list.push_back(std::vector<SpinFactor*>({
#         new SpinFactor("SF", SF_4Body::DtoV1V2_V1toP1P2_V2toP3P4_D          , 0, 3, 1, 2),
#         new SpinFactor("SF", SF_4Body::FF_12_34_L2                          , 0, 3, 1, 2)
#     }));
#
#     line_factor_list.push_back(std::vector<Lineshape*>{
#         new Lineshapes::RBW("K*(892)0", K892_0_M, K892_0_W, 1, M_14, FF::BL2),
#         new Lineshapes::RBW("K*(892)bar0", K892_0_M, K892_0_W, 1, M_14, FF::BL2)
#     });
#
#     amplitudes_list.push_back(new Amplitude{
#         "D0[D]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}",
#         mkvar("D0[D]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}_r", false, -1.01161, 0.203644),
#         mkvar("D0[D]{K(892)0{K+,pi-},K(892)~0{K-,pi+}}_i", false, 0.203644, 0.0190224),
#         line_factor_list.back(),
#         spin_factor_list.back(),
#         1});
#
#     DK3P_DI.amplitudes_B.push_back(amplitudes_list.back());
#
#
#     // Line 6
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-0cc5c8b0f0b0> in <module>()
#       2 for n, line in enumerate(lines):
#       3     print('    // Line', n)
# ----> 4     print(line.to_goofit(all_states[1:]), end='\n\n\n')
#
# ~/git/fitting/goofit/goofit_k3pi/decaylanguage/decaylanguage/decay/goofit.py in to_goofit(self, final_states)
#     290                 + self.make_spinfactor(final_states) + '\n'
#     291                 + self.make_linefactor(final_states) + '\n'
# --> 292                 + self.make_amplitude(final_states))
#     293
#     294     @classmethod
#
# ~/git/fitting/goofit/goofit_k3pi/decaylanguage/decaylanguage/decay/goofit.py in make_spinfactor(self, final_states)
#     247
#     248     def make_spinfactor(self, final_states):
# --> 249         spin_factors = self.spinfactors
#     250
#     251         intro = '    spin_factor_list.push_back(std::vector<SpinFactor*>({\n'
#
# ~/git/fitting/goofit/goofit_k3pi/decaylanguage/decaylanguage/decay/goofit.py in spinfactors(self)
#     146             return spinfactor
#     147
# --> 148         raise RuntimeError(f"Spinfactors not currenly included!: {self.spindetails()}")
#     149
#     150         #if self.decay_structure == DecayStructure.FF_12_34 :
#
# RuntimeError: Spinfactors not currenly included!: DtoV1S2_V1toP1P2_S2toP3P4_P

# %%
if cb.value:
    f.close()
    from builtins import print

    with open('DtoKpipipi_v2.cu') as f:
        for line in f:
            print(line, end='')
